# %% [markdown]
# ## 1. Introduction to Matplotlib
# Matplotlib is a widely used Python library for data visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in c:\users\sachin\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sachin\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sachin\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sachin\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sachin\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\sachin\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sachin\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sachin\appdata\roaming\python\python311\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sachin\appdata\roaming\python\python311\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sachin\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sachin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## 2. Basic Line Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, label='Sine Wave')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic Line Plot')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y, color='red', marker='o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# ## 4. Bar Chart

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 1, 8]
plt.bar(categories, values, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# %% [markdown]
# ## 5. Subplots

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
x = np.linspace(0, 10, 100)
axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title('Sine Wave')
axs[0, 1].plot(x, np.cos(x), 'r')
axs[0, 1].set_title('Cosine Wave')
axs[1, 0].scatter(np.random.rand(50), np.random.rand(50), color='g')
axs[1, 0].set_title('Random Scatter')
axs[1, 1].hist(np.random.randn(100), bins=10, color='purple')
axs[1, 1].set_title('Histogram')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. 3D Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
ax.plot_surface(X, Y, Z, cmap='viridis')
plt.title('3D Surface Plot')
plt.show()
